# %%
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# OPTIMIZER_DIRS = {
#     "AdamW (lr=5e-5)": Path("/scratch/shelvia.wongso/cbo_results/adamw/cifar10_resnet20/lr_5e-5_wd_2e-4_tf_0.2_nr_0.2"),
#     "AdamW (lr=1e-4)": Path("/scratch/shelvia.wongso/cbo_results/adamw/cifar10_resnet20/lr_1e-4_wd_2e-4_tf_0.2_nr_0.2"),
#     "AdamW (lr=5e-4)": Path("/scratch/shelvia.wongso/cbo_results/adamw/cifar10_resnet20/lr_5e-4_wd_2e-4_tf_0.2_nr_0.2"),
#     "AdamW (lr=1e-3)": Path("/scratch/shelvia.wongso/cbo_results/adamw/cifar10_resnet20/lr_1e-3_wd_2e-4_tf_0.2_nr_0.2"),
#     "AdamW (lr=5e-3)": Path("/scratch/shelvia.wongso/cbo_results/adamw/cifar10_resnet20/lr_5e-3_wd_2e-4_tf_0.2_nr_0.2"),
# }

# OPTIMIZER_DIRS = {
#     "SGD (lr=5e-2)": Path("/scratch/shelvia.wongso/cbo_results/sgd/cifar10_resnet20/lr_5e-2_wd_2e-4_tf_0.2_nr_0.4"),
#     "SGD (lr=1e-1)": Path("/scratch/shelvia.wongso/cbo_results/sgd/cifar10_resnet20/lr_1e-1_wd_2e-4_tf_0.2_nr_0.4"),
#     "SGD (lr=2e-1)": Path("/scratch/shelvia.wongso/cbo_results/sgd/cifar10_resnet20/lr_2e-1_wd_2e-4_tf_0.2_nr_0.4"),
#     "SGD (lr=3e-1)": Path("/scratch/shelvia.wongso/cbo_results/sgd/cifar10_resnet20/lr_3e-1_wd_2e-4_tf_0.2_nr_0.4"),
#     "SGD (lr=4e-1)": Path("/scratch/shelvia.wongso/cbo_results/sgd/cifar10_resnet20/lr_4e-1_wd_2e-4_tf_0.2_nr_0.4"),
# }

# OPTIMIZER_DIRS = {
#     "IVON (lr=0.5)": Path("/scratch/shelvia.wongso/cbo_results/ivon_price/cifar10_resnet20/lr_0.5_wd_2e-4_h0_0.5_ess_50000_tf_0.2_nr_0.2"),
#     "IVON (lr=1.0)": Path("/scratch/shelvia.wongso/cbo_results/ivon_price/cifar10_resnet20/lr_1.0_wd_2e-4_h0_0.5_ess_50000_tf_0.2_nr_0.2"),
#     "IVON (lr=1.5)": Path("/scratch/shelvia.wongso/cbo_results/ivon_price/cifar10_resnet20/lr_1.5_wd_2e-4_h0_0.5_ess_50000_tf_0.2_nr_0.2"),
#     "IVON (lr=2.0)": Path("/scratch/shelvia.wongso/cbo_results/ivon_price/cifar10_resnet20/lr_2.0_wd_2e-4_h0_0.5_ess_50000_tf_0.2_nr_0.2"),
#     "IVON (lr=2.5)": Path("/scratch/shelvia.wongso/cbo_results/ivon_price/cifar10_resnet20/lr_2.5_wd_2e-4_h0_0.5_ess_50000_tf_0.2_nr_0.2"),
#     "IVON (lr=3.0)": Path("/scratch/shelvia.wongso/cbo_results/ivon_price/cifar10_resnet20/lr_3.0_wd_2e-4_h0_0.5_ess_50000_tf_0.2_nr_0.2"),
#     "IVON (lr=3.5)": Path("/scratch/shelvia.wongso/cbo_results/ivon_price/cifar10_resnet20/lr_3.5_wd_2e-4_h0_0.5_ess_50000_tf_0.2_nr_0.2"),
# }

# OPTIMIZER_DIRS = {
#     "uCBOpt (lr=0.5)": Path("/scratch/shelvia.wongso/cbo_results/ucbopt/cifar10_resnet20/lr_0.5_wd_2e-4_h0_0.5_curv_0.0_tf_0.2_nr_0.2"),
#     "uCBOpt (lr=1.0)": Path("/scratch/shelvia.wongso/cbo_results/ucbopt/cifar10_resnet20/lr_1.0_wd_2e-4_h0_0.5_curv_0.0_tf_0.2_nr_0.2"),
#     "uCBOpt (lr=1.5)": Path("/scratch/shelvia.wongso/cbo_results/ucbopt/cifar10_resnet20/lr_1.5_wd_2e-4_h0_0.5_curv_0.0_tf_0.2_nr_0.2"),
#     "uCBOpt (lr=2.0)": Path("/scratch/shelvia.wongso/cbo_results/ucbopt/cifar10_resnet20/lr_2.0_wd_2e-4_h0_0.5_curv_0.0_tf_0.2_nr_0.2"),
#     "uCBOpt (lr=2.5)": Path("/scratch/shelvia.wongso/cbo_results/ucbopt/cifar10_resnet20/lr_2.5_wd_2e-4_h0_0.5_curv_0.0_tf_0.2_nr_0.2"),
#     "uCBOpt (lr=3.0)": Path("/scratch/shelvia.wongso/cbo_results/ucbopt/cifar10_resnet20/lr_3.0_wd_2e-4_h0_0.5_curv_0.0_tf_0.2_nr_0.2"),
#     "uCBOpt (lr=3.5)": Path("/scratch/shelvia.wongso/cbo_results/ucbopt/cifar10_resnet20/lr_3.5_wd_2e-4_h0_0.5_curv_0.0_tf_0.2_nr_0.2"),
# }

OPTIMIZER_DIRS = {
    r"uCBOpt ($\vartheta\rightarrow 0^+$)": Path("/scratch/shelvia.wongso/cbo_results/ucbopt/cifar10_resnet20/lr_3.0_wd_2e-4_h0_0.5_curv_0.0_tf_0.2_nr_0.2"),
    # r"uCBOpt ($\vartheta=5\cdot 10^{-6}$)": Path("/scratch/shelvia.wongso/cbo_results/ucbopt/cifar10_resnet20/lr_3.0_wd_2e-4_h0_0.5_curv_0.0_tf_0.2_nr_0.2"),
    "IVON ": Path("/scratch/shelvia.wongso/cbo_results/ivon_price/cifar10_resnet20/lr_3.0_wd_2e-4_h0_0.5_ess_50000_tf_0.2_nr_0.2"),
    "SGD": Path("/scratch/shelvia.wongso/cbo_results/sgd/cifar10_resnet20/lr_3e-1_wd_2e-4_tf_0.2_nr_0.2"),
    "AdamW": Path("/scratch/shelvia.wongso/cbo_results/adamw/cifar10_resnet20/lr_5e-3_wd_2e-4_tf_0.2_nr_0.2"),
}

SEEDS = range(5)

# %%
def find_latest_csv(seed_dir: Path, split: str) -> Path | None:
    candidates = sorted(seed_dir.glob(f"*/{split}.csv"))
    if not candidates:
        return None
    return candidates[-1]  # latest by lexicographic timestamp folder name

# %%
def load_split_across_seeds(root: Path, split: str, value_col: str, seeds=SEEDS):
    series_list = []

    for seed in seeds:
        seed_dir = root / f"seed={seed}"
        csv_path = find_latest_csv(seed_dir, split)

        if csv_path is None:
            print(f"[WARN] Missing {split}.csv for {root.name}, seed={seed}")
            continue

        df = pd.read_csv(csv_path)

        if "epoch" not in df.columns or value_col not in df.columns:
            print(f"[WARN] Missing required columns in {csv_path}")
            continue

        s = df[["epoch", value_col]].copy()
        s = s.rename(columns={value_col: f"seed={seed}"})
        series_list.append(s)

    if not series_list:
        return None

    # Merge on epoch so all seeds are aligned
    merged = series_list[0]
    for s in series_list[1:]:
        merged = pd.merge(merged, s, on="epoch", how="inner")

    value_cols = [c for c in merged.columns if c != "epoch"]
    merged["mean"] = merged[value_cols].mean(axis=1)
    merged["std"] = merged[value_cols].std(axis=1, ddof=1)

    return merged[["epoch", "mean", "std"]]

# %%
def collect_all_results(optimizer_dirs, seeds=SEEDS):
    results = {}

    metrics = {
        "train_loss": ("train", "loss"),
        "test_loss": ("test", "loss"),
        "train_acc": ("train", "acc"),
        "test_acc": ("test", "acc"),
    }

    for opt_name, root in optimizer_dirs.items():
        results[opt_name] = {}
        for metric_name, (split, col) in metrics.items():
            out = load_split_across_seeds(root, split, col, seeds=seeds)
            results[opt_name][metric_name] = out

    return results

# %%
def plot_2x2_metrics(results, suptitle=None, savepath=None):
    fig, axes = plt.subplots(2, 2, figsize=(12, 8), sharex=True)

    base = {"linewidth": 1.8}
    styles = {
        r"uCBOpt ($\vartheta\rightarrow 0^+$)": {**base, "linewidth": 2.5, "zorder": 3},
        r"uCBOpt ($\vartheta=5\cdot 10^{-6}$)": {**base, "linestyle": ":", "linewidth": 2.5, "zorder": 4},
        "IVON": base,
        "SGD": base,
        "AdamW": base,
    }

    metrics = [
        ("train_loss", "Train Loss"),
        ("test_loss", "Test Loss"),
        ("train_acc", "Train Accuracy"),
        ("test_acc", "Test Accuracy"),
    ]

    for ax, (metric_name, ylabel) in zip(axes.flat, metrics):
        for opt_name, opt_results in results.items():
            df = opt_results.get(metric_name)
            if df is None:
                print(f"[WARN] No data for {opt_name} - {metric_name}")
                continue

            x = df["epoch"].to_numpy()
            y = df["mean"].to_numpy()
            std = df["std"].to_numpy()

            style = styles.get(opt_name.strip(), {})

            line, = ax.plot(x, y, label=opt_name, **style)
            line_color = line.get_color()

            ax.fill_between(
                x,
                y - std,
                y + std,
                color=line_color,
                alpha=0.15,
                zorder=style.get("zorder", 1) - 0.1,
            )

        ax.set_title(ylabel)
        ax.set_xlabel("Epoch")
        ax.set_ylabel(ylabel)
        ax.grid(True, alpha=0.3)

    handles, labels = axes[0, 0].get_legend_handles_labels()
    fig.legend(handles, labels, loc="upper center", ncol=len(labels), bbox_to_anchor=(0.5, 0.95))

    if suptitle is not None:
        fig.suptitle(suptitle, fontsize=13)

    plt.tight_layout(rect=[0, 0, 1, 0.95 if suptitle else 1])

    if savepath is not None:
        plt.savefig(savepath, dpi=200, bbox_inches="tight")
    plt.show()

# %%
results = collect_all_results(OPTIMIZER_DIRS, seeds=SEEDS)

# %%
plot_2x2_metrics(results, suptitle="CIFAR-10 ResNet20 (Train Fraction = 20%, Label Noise = 20%)")
